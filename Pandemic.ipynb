# %%
from scipy.stats import norm
import random
import time

# %%
peopleDictionary = []

# %%
# simulation of a single person
class Person():
    def __init__(self, startingImmunity):
        if random.randint(0,100)<startingImmunity:
            self.immunity = True
        else:
            self.immunity = False
        self.contagiousness = 0
        self.mask = False
        self.contagiousDays = 0
        #use gaussian distribution for number of friends; average is 5 friends
        self.friends = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0))
    def wearMask(self):
        self.contagiousness /= 2

# %%
def initiateSim():
    numPeople = int(input("Population: "))
    startingImmunity = int(input("Percentage of people with natural immunity: "))
    startingInfecters = int(input("How many people will be infectious at t=0: "))
    for x in range(0,numPeople):
        peopleDictionary.append(Person(startingImmunity))
    for x in range(0,startingInfecters):
        peopleDictionary[random.randint(0,len(peopleDictionary)-1)].contagiousness = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0)*10)
    daysContagious = int(input("How many days contagious: "))
    lockdownDay = int(input("Day for lockdown to be enforced: "))
    maskDay = int(input("Day for masks to be used: "))
    return daysContagious, lockdownDay, maskDay

# %%
def runDay(daysContagious, lockdown):
    #this section simulates the spread, so it only operates on contagious people, thus:
    for person in [person for person in peopleDictionary if person.contagiousness>0 and person.friends>0]:
        peopleCouldMeetToday = int(person.friends/2)
        if peopleCouldMeetToday > 0:
            peopleMetToday = random.randint(0,peopleCouldMeetToday)
        else:
            peopleMetToday = 0
            
        if lockdown == True:
            peopleMetToday= 0
            
        for x in range(0,peopleMetToday):
            friendInQuestion = peopleDictionary[random.randint(0,len(peopleDictionary)-1)]
            if random.randint(0,100)<person.contagiousness and friendInQuestion.contagiousness == 0 and friendInQuestion.immunity==False:
                friendInQuestion.contagiousness = int((norm.rvs(size=1,loc=0.5,scale=0.15)[0]*10).round(0)*10)
                print(peopleDictionary.index(person), " >>> ", peopleDictionary.index(friendInQuestion))

# %%
for person in [person for person in peopleDictionary if person.contagiousness>0]:
        person.contagiousDays += 1
        if person.contagiousDays > daysContagious:
            person.immunity = True
            person.contagiousness = 0
            print("|||", peopleDictionary.index(person), " |||")

# %%
lockdown = False
daysContagious, lockdownDay, maskDay = initiateSim()
saveFile = open("pandemicsave3.txt", "a")
for x in range(0,100):
    if x==lockdownDay:
        lockdown = True
        
    if x == maskDay:
        for person in peopleDictionary:
            person.wearMask()
            
    print("DAY ", x)
    runDay(daysContagious,lockdown)
    write = str(len([person for person in peopleDictionary if person.contagiousness>0])) + "\n"
    saveFile.write(write)
    
    print(len([person for person in peopleDictionary if person.contagiousness>0]), " people are contagious on this day.")
saveFile.close()
# Out:
# Population: 10000
# Percentage of people with natural immunity: 1
# How many people will be infectious at t=0: 1
# How many days contagious: 7
# Day for lockdown to be enforced: 10
# Day for masks to be used: 10
# DAY  0
# 1010  >>>  1101
# 2  people are contagious on this day.
# DAY  1
# 1101  >>>  175
# 1101  >>>  1521
# 4  people are contagious on this day.
# DAY  2
# 175  >>>  2576
# 1101  >>>  5078
# 6  people are contagious on this day.
# DAY  3
# 175  >>>  9332
# 1010  >>>  5806
# 1521  >>>  6267
# 5078  >>>  5146
# 5078  >>>  8099
# 11  people are contagious on this day.
# DAY  4
# 1010  >>>  2319
# 5078  >>>  8546
# 5078  >>>  9581
# 5146  >>>  7907
# 5146  >>>  7850
# 5806  >>>  8151
# 5806  >>>  3203
# 6267  >>>  3145
# 8099  >>>  7058
# 20  people are contagious on this day.
# DAY  5
# 1010  >>>  5208
# 1101  >>>  9346
# 5078  >>>  9287
# 5806  >>>  9886
# 5806  >>>  8841
# 6267  >>>  3522
# 7850  >>>  7833
# 7907  >>>  643
# 8099  >>>  4802
# 8099  >>>  9485
# 9581  >>>  9632
# 31  people are contagious on this day.
# DAY  6
# 643  >>>  956
# 2319  >>>  4142
# 4802  >>>  8124
# 7833  >>>  4578
# 7907  >>>  8699
# 8841  >>>  9730
# 9332  >>>  7036
# 9886  >>>  2712
# 39  people are contagious on this day.
# DAY  7
# 175  >>>  9161
# 643  >>>  6981
# 2712  >>>  9495
# 4142  >>>  7039
# 4802  >>>  5427
# 5146  >>>  2066
# 5806  >>>  5609
# 7833  >>>  4874
# 7850  >>>  9142
# 7907  >>>  941
# 7907  >>>  5488
# 8099  >>>  9468
# 8151  >>>  8529
# 8699  >>>  4404
# 9287  >>>  666
# 9332  >>>  1428
# 9730  >>>  717
# 56  people are contagious on this day.
# DAY  8
# 643  >>>  9607
# 717  >>>  6641
# 941  >>>  7496
# 941  >>>  8990
# 1010  >>>  8794
# 1101  >>>  5371
# 1428  >>>  3611
# 2066  >>>  5640
# 3203  >>>  3971
# 4802  >>>  1856
# 5078  >>>  4028
# 5146  >>>  9343
# 6981  >>>  3373
# 7833  >>>  8303
# 8099  >>>  5153
# 8151  >>>  15
# 8699  >>>  3187
# 8841  >>>  2108
# 9161  >>>  95
# 9161  >>>  9610
# 9346  >>>  2983
# 9346  >>>  4855
# 9485  >>>  1797
# 9495  >>>  690
# 9581  >>>  9345
# 9886  >>>  5633
# 9886  >>>  8683
# 83  people are contagious on this day.
# DAY  9
# 15  >>>  4351
# 95  >>>  4244
# 95  >>>  5538
# 175  >>>  2410
# 666  >>>  2071
# 1521  >>>  8243
# 2066  >>>  8895
# 2066  >>>  4479
# 2576  >>>  5723
# 2712  >>>  2092
# 2983  >>>  7230
# 3187  >>>  3261
# 3187  >>>  4971
# 3373  >>>  4927
# 3373  >>>  9812
# 3971  >>>  5477
# 3971  >>>  5830
# 4028  >>>  9567
# 4028  >>>  4080
# 4142  >>>  7835
# 4802  >>>  7123
# 5078  >>>  8331
# 5146  >>>  1714
# 5153  >>>  8319
# 5208  >>>  2961
# 5371  >>>  476
# 5371  >>>  170
# 5427  >>>  6306
# 5488  >>>  4710
# 5633  >>>  9893
# 5633  >>>  6012
# 5640  >>>  4789
# 5806  >>>  4036
# 5806  >>>  991
# 6267  >>>  4568
# 6267  >>>  8678
# 7036  >>>  7586
# 7036  >>>  4334
# 7496  >>>  6301
# 7833  >>>  6522
# 8099  >>>  5243
# 8099  >>>  132
# 8303  >>>  2096
# 8794  >>>  7808
# 9287  >>>  7938
# 9287  >>>  1944
# 9287  >>>  8569
# 9332  >>>  4213
# 9343  >>>  8983
# 9345  >>>  9874
# 9346  >>>  4402
# 9485  >>>  7880
# 9581  >>>  5995
# 9581  >>>  860
# 9632  >>>  6279
# 9632  >>>  6773
# 9730  >>>  1824
# 9730  >>>  4993
# 9886  >>>  3552
# 142  people are contagious on this day.
# DAY  10
# 142  people are contagious on this day.
# DAY  11
# 142  people are contagious on this day.
# DAY  12
# 142  people are contagious on this day.
# DAY  13
# 142  people are contagious on this day.
# DAY  14
# 142  people are contagious on this day.
# DAY  15
# 142  people are contagious on this day.
# DAY  16
# 142  people are contagious on this day.
# DAY  17
# 142  people are contagious on this day.
# DAY  18
# 142  people are contagious on this day.
# DAY  19
# 142  people are contagious on this day.
# DAY  20
# 142  people are contagious on this day.
# DAY  21
# 142  people are contagious on this day.
# DAY  22
# 142  people are contagious on this day.
# DAY  23
# 142  people are contagious on this day.
# DAY  24
# 142  people are contagious on this day.
# DAY  25
# 142  people are contagious on this day.
# DAY  26
# 142  people are contagious on this day.
# DAY  27
# 142  people are contagious on this day.
# DAY  28
# 142  people are contagious on this day.
# DAY  29
# 142  people are contagious on this day.
# DAY  30
# 142  people are contagious on this day.
# DAY  31
# 142  people are contagious on this day.
# DAY  32
# 142  people are contagious on this day.
# DAY  33
# 142  people are contagious on this day.
# DAY  34
# 142  people are contagious on this day.
# DAY  35
# 142  people are contagious on this day.
# DAY  36
# 142  people are contagious on this day.
# DAY  37
# 142  people are contagious on this day.
# DAY  38
# 142  people are contagious on this day.
# DAY  39
# 142  people are contagious on this day.
# DAY  40
# 142  people are contagious on this day.
# DAY  41
# 142  people are contagious on this day.
# DAY  42
# 142  people are contagious on this day.
# DAY  43
# 142  people are contagious on this day.
# DAY  44
# 142  people are contagious on this day.
# DAY  45
# 142  people are contagious on this day.
# DAY  46
# 142  people are contagious on this day.
# DAY  47
# 142  people are contagious on this day.
# DAY  48
# 142  people are contagious on this day.
# DAY  49
# 142  people are contagious on this day.
# DAY  50
# 142  people are contagious on this day.
# DAY  51
# 142  people are contagious on this day.
# DAY  52
# 142  people are contagious on this day.
# DAY  53
# 142  people are contagious on this day.
# DAY  54
# 142  people are contagious on this day.
# DAY  55
# 142  people are contagious on this day.
# DAY  56
# 142  people are contagious on this day.
# DAY  57
# 142  people are contagious on this day.
# DAY  58
# 142  people are contagious on this day.
# DAY  59
# 142  people are contagious on this day.
# DAY  60
# 142  people are contagious on this day.
# DAY  61
# 142  people are contagious on this day.
# DAY  62
# 142  people are contagious on this day.
# DAY  63
# 142  people are contagious on this day.
# DAY  64
# 142  people are contagious on this day.
# DAY  65
# 142  people are contagious on this day.
# DAY  66
# 142  people are contagious on this day.
# DAY  67
# 142  people are contagious on this day.
# DAY  68
# 142  people are contagious on this day.
# DAY  69
# 142  people are contagious on this day.
# DAY  70
# 142  people are contagious on this day.
# DAY  71
# 142  people are contagious on this day.
# DAY  72
# 142  people are contagious on this day.
# DAY  73
# 142  people are contagious on this day.
# DAY  74
# 142  people are contagious on this day.
# DAY  75
# 142  people are contagious on this day.
# DAY  76
# 142  people are contagious on this day.
# DAY  77
# 142  people are contagious on this day.
# DAY  78
# 142  people are contagious on this day.
# DAY  79
# 142  people are contagious on this day.
# DAY  80
# 142  people are contagious on this day.
# DAY  81
# 142  people are contagious on this day.
# DAY  82
# 142  people are contagious on this day.
# DAY  83
# 142  people are contagious on this day.
# DAY  84
# 142  people are contagious on this day.
# DAY  85
# 142  people are contagious on this day.
# DAY  86
# 142  people are contagious on this day.
# DAY  87
# 142  people are contagious on this day.
# DAY  88
# 142  people are contagious on this day.
# DAY  89
# 142  people are contagious on this day.
# DAY  90
# 142  people are contagious on this day.
# DAY  91
# 142  people are contagious on this day.
# DAY  92
# 142  people are contagious on this day.
# DAY  93
# 142  people are contagious on this day.
# DAY  94
# 142  people are contagious on this day.
# DAY  95
# 142  people are contagious on this day.
# DAY  96
# 142  people are contagious on this day.
# DAY  97
# 142  people are contagious on this day.
# DAY  98
# 142  people are contagious on this day.
# DAY  99
# 142  people are contagious on this day.
